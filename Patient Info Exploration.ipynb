# %%
import pandas as pd

# %%
patient = pd.read_csv('data/Train/Patient_Profile.csv')
patient.head()
# Out:
#    Patient_ID  Online_Follower  LinkedIn_Shared  Twitter_Shared  \
# 0      516956                0                0               0
# 1      507733                0                0               0
# 2      508307                0                0               0
# 3      512612                0                0               0
# 4      521075                0                0               0
#
#    Facebook_Shared Income Education_Score Age First_Interaction City_Type  \
# 0                0      1              90  39         18-Jun-03       NaN
# 1                0      1            None  40         20-Jul-03         H
# 2                0      3              87  46         02-Nov-02         D
# 3                0      1              75  47         02-Nov-02         D
# 4                0      3            None  80         24-Nov-02         H
#
#    Employer_Category
# 0  Software Industry
# 1  Software Industry
# 2               BFSI
# 3          Education
# 4             Others

# %%
len(patient.index)
# Out:
# 37633

# %%
patient[['Online_Follower','LinkedIn_Shared', 'Twitter_Shared', 'Facebook_Shared']].sum()
# Out:
# Online_Follower     848
# LinkedIn_Shared    1019
# Twitter_Shared      813
# Facebook_Shared     886
# dtype: int64

# %%
patient.City_Type.value_counts(dropna=False)
# Out:
# NaN    23384
# B       2662
# H       2517
# A       1729
# D       1704
# G       1352
# E       1217
# C       1216
# I       1036
# F        816
# Name: City_Type, dtype: int64

# %%
patient[patient.Age == 'None']
# Out:
#        Patient_ID  Online_Follower  LinkedIn_Shared  Twitter_Shared  \
# 5          502103                0                0               0
# 6          528501                0                0               0
# 7          519202                0                0               0
# 8          521359                0                0               0
# 13         510954                0                0               0
# 15         511565                0                0               0
# 16         495861                0                0               0
# 19         514739                0                0               0
# 22         492934                0                0               0
# 23         504923                0                0               0
# 24         521281                0                0               0
# 25         526333                0                0               0
# 26         489594                0                0               0
# ...
