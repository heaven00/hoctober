# %%
import pandas as pd

# %%
trial3data = pd.read_csv('trial3_data.csv', low_memory=False)

# %%
trial3data.head()
# Out:
#    Patient_ID  Health_Camp_ID  Var1  Var2  Var3  Var4  Var5  target  day  \
# 0      489652            6578     4     0     0     0     2     1.0   10
# 1      507246            6578    45     5     0     0     7     0.0   18
# 2      491371            6578     0     0     0     0     0     0.0   24
# 3      485995            6578     0     0     0     0     0     1.0    1
# 4      511519            6578     0     0     0     0     0     1.0   26
#
#    month           ...            Category2_D  Category2_E  Category2_F  \
# 0      9           ...                    0.0          0.0          0.0
# 1      8           ...                    0.0          0.0          0.0
# 2      7           ...                    0.0          0.0          0.0
# 3     10           ...                    0.0          0.0          0.0
# 4      9           ...                    0.0          0.0          0.0
#
#    Category2_G  Category3_1  Category3_2  Online_Follower  \
# ...
